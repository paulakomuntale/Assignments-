# %%
#Simple demo
#import random

import random

#environment 
goal=5
position=0

#output
print('Robot is at position',position)
while position!=goal:
    #action
    action=random.choice([-1,1])
    position+=action
    print('Robot moved to position',position)
# Out:
# Robot is at position 0
# Robot moved to position 1
# Robot moved to position 2
# Robot moved to position 3
# Robot moved to position 2
# Robot moved to position 1
# Robot moved to position 0
# Robot moved to position 1
# Robot moved to position 2
# Robot moved to position 3
# Robot moved to position 4
# Robot moved to position 5

# %%
# Simple Demo of Reinforcement Learning
# Import Random
# Give reward to a Robot for reaching the right goal interns of direction
import random

# Environment
goal = 5
position = 0

# Output
print('Robot starts at position: ', position)

while position != goal:
    # Action, Random action
    action = random.choice(['LEFT', 'RIGHT'])
    
    if action == "RIGHT":
        position += 1
    else:
        position = max(0, position - 1)
    
    # Rewards
    if position == goal:
        reward = 100
    else:
        reward = -1
    
    # Output the action of the robot
    print(f"Action: {action:5} position: {position} Reward: {reward}")

print("\nRobot has Reached our goal")
# Out:
# Robot starts at position:  0
# Action: RIGHT position: 1 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: RIGHT position: 1 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: RIGHT position: 1 Reward: -1
# Action: RIGHT position: 2 Reward: -1
# Action: RIGHT position: 3 Reward: -1
# Action: RIGHT position: 4 Reward: -1
# Action: LEFT  position: 3 Reward: -1
# Action: RIGHT position: 4 Reward: -1
# Action: RIGHT position: 5 Reward: 100
#
# Robot has Reached our goal
